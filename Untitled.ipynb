# %%
from pathlib import Path
import rasterio
from rasterio.plot import show

test = Path("/home/scrappy/topo/data/test.tif")
img = rasterio.open(test)
show(img)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <AxesSubplot:>
